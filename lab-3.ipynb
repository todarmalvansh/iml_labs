# %% [markdown]
#  <h1>practical 3</h1>

# %% [markdown]
# **1) to split an array of 14 elements into 3 arrays,each with 2,4, and 8 elements in theoriginal order**

# %%
import numpy as np

# %%
orignal_array = np. arange(14)

spilt_array = np. split(orignal_array,[2,6])

for i, arr in enumerate (spilt_array,1):
    print(f"split array {i}:",arr)

# %% [markdown]
# **2) to stack arrays horizontally (column wise)**

# %%
array1 =np. arange(2)
array2 =np. arange(2,6)
array3 =np. arange(6,14)

st_array = np. hstack((array1,array2,array3))
print("stacked Array")
print(st_array)
